# %%
import pandas as pd
import zipfile as zp

# %%
zf = zp.ZipFile('Train.csv.zip')
df = pd.read_csv(zf.open('Train.csv'))
# Out:
# /home/deepak/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (13,39,40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate        ...         \
# 0                      68.0       Low  11/16/2006 0:00        ...
# 1                    4640.0       Low   3/26/2004 0:00        ...
# 2                    2838.0      High   2/26/2004 0:00        ...
# 3                    3486.0      High   5/19/2011 0:00        ...
# 4                     722.0    Medium   7/23/2009 0:00        ...
#
#   Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# ...

# %%
import missingno as msno

# %%
msno.matrix(df)

# %%
df.columns
# Out:
# Index(['SalesID', 'SalePrice', 'MachineID', 'ModelID', 'datasource',
#        'auctioneerID', 'YearMade', 'MachineHoursCurrentMeter', 'UsageBand',
#        'saledate', 'fiModelDesc', 'fiBaseModel', 'fiSecondaryDesc',
#        'fiModelSeries', 'fiModelDescriptor', 'ProductSize',
#        'fiProductClassDesc', 'state', 'ProductGroup', 'ProductGroupDesc',
#        'Drive_System', 'Enclosure', 'Forks', 'Pad_Type', 'Ride_Control',
#        'Stick', 'Transmission', 'Turbocharged', 'Blade_Extension',
#        'Blade_Width', 'Enclosure_Type', 'Engine_Horsepower', 'Hydraulics',
#        'Pushblock', 'Ripper', 'Scarifier', 'Tip_Control', 'Tire_Size',
#        'Coupler', 'Coupler_System', 'Grouser_Tracks', 'Hydraulics_Flow',
#        'Track_Type', 'Undercarriage_Pad_Width', 'Stick_Length', 'Thumb',
#        'Pattern_Changer', 'Grouser_Type', 'Backhoe_Mounting', 'Blade_Type',
#        'Travel_Controls', 'Differential_Type', 'Steering_Controls'],
#       dtype='object')

# %%
df = df[['SalesID', 'SalePrice', 'MachineID', 'ModelID', 'datasource',
       'auctioneerID', 'YearMade', 'MachineHoursCurrentMeter']]

# %%
msno.matrix(df)

# %%
tmp = df.dropna()

# %%
msno.matrix(tmp)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()

# %%
df = df.dropna()

# %%
df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  YearMade  MachineHoursCurrentMeter
# 0  1139246      66000     999089     3157      2004                      68.0
# 1  1139248      57000     117657       77      1996                    4640.0
# 2  1139249      10000     434808     7009      2001                    2838.0
# 3  1139251      38500    1026470      332      2001                    3486.0
# 4  1139253      11000    1057373    17311      2007                     722.0

# %%
X, y = df[['SalesID','MachineID','ModelID','YearMade','MachineHoursCurrentMeter']],df['SalePrice']

# %%
from sklearn.model_selection import train_test_split

# %%
knn = KNeighborsRegressor()
knn.fit(X,y,distance = 'inverse')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-99373937a16f> in <module>()
#       1 knn = KNeighborsRegressor()
# ----> 2 knn.fit(X,y,distance = 'inverse')
#
# TypeError: fit() got an unexpected keyword argument 'distance'

# %%
knn = KNeighborsRegressor(weights = 'distance')

# %%
knn.fit(X,y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#           weights='distance')

# %%
zf1 = zp.ZipFile('Test.csv.zip')
df1 = pd.read_csv(zf1.open('Test.csv'))

# %%
df1 = df1[['SalesID','MachineID', 'ModelID', 'datasource',
       'auctioneerID', 'YearMade']

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-1a7fe13cc71d> in <module>()
# ----> 1 df1.interpolate(method='spline')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6032                                     limit_area=limit_area,
#    6033                                     inplace=inplace, downcast=downcast,
# -> 6034                                     **kwargs)
#    6035
#    6036         if inplace:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in interpolate(self, **kwargs)
#    3700
#    3701     def interpolate(self, **kwargs):
# -> 3702         return self.apply('interpolate', **kwargs)
#    3703
#    3704     def shift(self, **kwargs):
#
# ...
